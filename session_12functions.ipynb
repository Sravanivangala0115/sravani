# %% [markdown]
# ## function
#
# - reuse of the code block
#
# - function also called as method
#
# - function without arguments
#
# - function with arguments
#
# - function with default arguments
#
# - function with keyword arguments(kwargs)
#
# - function with local and global variable
#
# - function with return
#
# - function in function

# %% [markdown]
# **functions without arguments**

# %%
# syntax
def <function name>():
    <write ur lines here>

# %%
num1=100
num2=200
add=num1+num2
print(f'the addition of {num1} and {num2} is: {add}')
# Out:
# the addition of 100 and 200 is: 300

# %%
def addition():
    num1=eval(input('enter num1:'))
    num2=eval(input('enter num2:'))
    add=num1+num2
    print(f'the addition of {num1} and {num2} is : {add}')

# %% [markdown]
# **call the function**

# %%
addition()
# Out:
# enter num1: 100
# enter num2: 200
# the addition of 100 and 200 is : 300

# %%
def addition():
    num1=eval(input('enter num1:'))
    num2=eval(input('enter num2:'))
    add=num1+num2
    print(f'the addition of {num1} and {num2} is : {add}')
addition()
# Out:
# enter num1: 100
# enter num2: 200
# the addition of 100 and 200 is : 300

# %% [markdown]
# **note**
#
# - function name rules same as variable names
#
#     - no special characters
#
#     - no numbers before
#
#     - no space between words etc
#
# - function name should not be any keywords
#
# - function name should not be any package names
#
# - function name should not be ur notebook name
#
# - function name should not be any variables which is using inside that function
#
# - while defining the function we doesnot know whether the error is there or not
#
# - for that we need to call the function

# %%
def addition1():
    n1=eval(input('enter n1:'))
    n2=eval(input('entern2:'))
    add1=n11+n2
    print(f'the addition of {n1} and {n2} is : {add1}')

# %%
addition1()
# Out:
# enter n1: 1000
# entern2: 200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 addition1()
#
# Cell In[8], line 4, in addition1()
#       2 n1=eval(input('enter n1:'))
#       3 n2=eval(input('entern2:'))
# ----> 4 add1=n11+n2
#       5 print(f'the addition of {n1} and {n2} is : {add1}')
#
# NameError: name 'n11' is not defined

# %%
try:
    def addition2():
        n1=eval(input('enter n1:'))
        n2=eval(input('entern2:'))
        add1=n1+n2
        print(f'the addition of {n1} and {n2} is : {add1}')
except Exception as e:
    print(e)
addition2()
# Out:
# enter n1: 100
# entern2: 200
# the addition of 100 and 200 is : 300

# %%
def addition2():
    try:
        n1=eval(input('enter n1:'))
        n2=eval(input('entern2:'))
        add1=n1+n2
        print(f'the addition of {n1} and {n2} is : {add1}')
    except Exception as e:
        print(e)
addition2()
# Out:
# enter n1: 100
# entern2: 200
# the addition of 100 and 200 is : 300

# %% [markdown]
# **note**
# - try and except should write inside the function

# %%
def AVG():
    try:
        n1=eval(input('enter a num1:'))
        n2=eval(input('enter a num2:'))
        n3=eval(input('enter a num3:'))
        avg=(n1+n2+n3)/3
        avg1=round(avg,2)
        print(f'the avg of {n1},{n2} and {n3} is : {avg1}')
    except Exception as e:
        print(e)
AVG()
# Out:
# enter a num1: 100
# enter a num2: 200
# enter a num3: 300
# the avg of 100,200 and 300 is : 200.0

# %%
def NAME():
    try:
        name=input('enter the name:')
        age=eval(input('enter the age:'))
        city=input('enter the city:')
        print(f'my name is {name},im {age} years old and come from {city}')
    except Exception as e:
        print(e)
NAME()
# Out:
# enter the name: python
# enter the age: 10
# enter the city: hyd
# my name is python,im 10 years old and come from hyd

# %%
def AREA():
    try:
        radius=eval(input('enter the radius of circle:'))
        pi=3.14
        area=pi*radius*radius
        print(f'the area of circle is : {area}')
    except Exception as e:
        print(e)
AREA()
# Out:
# enter the radius of circle: 10
# the area of circle is : 314.0

# %%
def AREA():
    try:
        breadth=eval(input('enter the breadth of the right angle triangle:'))
        height=eval(input('enter the height of the right angle triangle:'))
        area=0.5*breadth*height
        print(f'the area of right angle triangle is : {area}')
    except Exception as e:
        print(e)

AREA()
# Out:
# enter the breadth of the right angle triangle: 10
# enter the height of the right angle triangle: 20
# the area of right angle triangle is : 100.0

# %%
def amount():
    try:
        bill_amount=eval(input('enter the bill amount:'))
        tip_amount=eval(input('enter the tip amount:'))
        total_bill=bill_amount+tip_amount
        print(f'the total bill is : {total_bill}')
    except Exception as e:
        print(e)

amount()
# Out:
# enter the bill amount: 100
# enter the tip amount: 50
# the total bill is : 150

# %%
def amount():
    try:
        bill_amount=eval(input('enter the bill amount:'))
        tip_amount=eval(input('enter the tip amount:'))
        tip_percentage=10
        total_bill=bill_amount+tip_amount*tip_percentage/100
        print(f'the total bill is : {total_bill}')
    except Exception as e:
        print(e)

amount()
# Out:
# enter the bill amount: 100
# enter the tip amount: 20
# the total bill is : 102.0

# %%
def AREA():
    try:
        length=eval(input('enter the length of the rectangle:'))
        breadth=eval(input('enter the breadth of the rectangle:'))
        area=length*breadth
        print(f'the area of rectangle is : {area}')
    except Exception as e:
        print(e)

AREA()
# Out:
# enter the length of the rectangle: 10
# enter the breadth of the rectangle: 20
# the area of rectangle is : 200

# %%
def VOL():
    try:
        radius=eval(input('enter the radius of sphere:'))
        pi=3.14
        vol=pi*radius*radius*radius
        print(f'the volume of sphere is : {vol}')
    except Exception as e:
        print(e)

VOL()
# Out:
# enter the radius of sphere: 10
# the volume of sphere is : 3140.0

# %%
def CON():
    try:
        dollars=eval(input('enter a number:'))
        rupees=dollars*85
        print(f'{dollars}$={rupees}INR')
    except Exception as e:
        print(e)
CON()
# Out:
# enter a number: 1
# 1$=85INR

# %%
def CON():
    try:
        weight=eval(input('enter a number:'))
        pounds=weight*2.2
        print(f'{weight}kg={pounds}pounds')
    except Exception as e:
        print(e)
CON()
# Out:
# enter a number: 1
# 1kg=2.2pounds

# %%
def addition():
    n1=eval(input('enter num1:'))
    n2=eval(input('enter num2:'))
    add=n1+n2
    print(f'the addition of {n1} and {n2} is : {add}')
addition()
# Out:
# enter num1: 100
# enter num2: 200
# the addition of 100 and 200 is : 300

# %% [markdown]
# **functions with arguments**

# %% [markdown]
# - how many variables are there inside the function
#
#    - in above **addition** function 3 variables are there : n1, n2, add
#
# - how many input variables are there
#
#    - input variable means the variable access the values from user as a input : **n1, n2**
#
# - how many output variables are there
#
#    - output variable means the variable created because of some operations : **add**
#
# - **dont touch the output variable**

# %%
def addition1(n1,n2):
    add=n1+n2
    print(f'the addition of {n1} and {n2} is : {add}')
addition1(100,200)
# Out:
# the addition of 100 and 200 is : 300

# %%
def addition1(n1,n2):
    print('n1 is:', n1)
    print('n2 is:', n2)
    add=n1+n2
    print(f'the addition of {n1} and {n2} is : {add}')
addition1(100,200)
# Out:
# n1 is: 100
# n2 is: 200
# the addition of 100 and 200 is : 300

# %%
def addition():
    n1=eval(input('enter num1:'))
    n2=eval(input('enter num2:'))
    add=n1+n2
    print(f'the addition of {n1} and {n2} is : {add}')

def addition1(n1,n2):
    add=n1+n2
    print(f'the addition of {n1} and {n2} is : {add}')

def addition1(n1):
    n2=eval(input('enter num2:'))
    add=n1+n2
    print(f'the addition of {n1} and {n2} is : {add}')

# %%
def AVG(n1,n2,n3):
    avg=(n1+n2+n3)/3
    avg1=round(avg,2)
    print(f'the average of {n1} , {n2} and {n3} is : {avg1}')
AVG(100,200,300)

def AVG1(n1,n2):
    n3=eval(input('enter num3:'))
    avg=(n1+n2+n3)/3
    avg1=round(avg,2)
    print(f'the average of {n1} , {n2} and {n3} is : {avg1}')
AVG1(100,200)

def AVG2(n1):
    n2=eval(input('enter num2:'))
    n3=eval(input('enter num3:'))
    avg=(n1+n2+n3)/3
    avg1=round(avg,2)
    print(f'the average of {n1} , {n2} and {n3} is : {avg1}')
AVG2(100)

def AVG3():
    n1=eval(input('enter num1:'))
    n2=eval(input('enter num2:'))
    n3=eval(input('enter num3:'))
    avg=(n1+n2+n3)/3
    avg1=round(avg,2)
    print(f'the average of {n1} , {n2} and {n3} is : {avg1}')
AVG3()
# Out:
# the average of 100 , 200 and 300 is : 200.0
# enter num3: 300
# the average of 100 , 200 and 300 is : 200.0
# enter num2: 200
# enter num3: 300
# the average of 100 , 200 and 300 is : 200.0
# enter num1: 100
# enter num2: 200
# enter num3: 300
# the average of 100 , 200 and 300 is : 200.0

# %% [markdown]
# **function with default arguments**

# %%
def bill_amount1(bill,tip_per=20):
    tip_amount=bill*tip_per/100
    total_bill=bill+tip_amount
    print('total bill is:',total_bill)
bill_amount1(1000)
# Out:
# total bill is: 1200.0

# %% [markdown]
# - in above function the tip percentage is fixed as 20
#
# - this is called default arguments
#
# - while calling the function no need to provide tip percentage again
#
# - if you provide again the value will be change

# %%
def AVG(n1,n2,n3=300):
    print('n1 is:',n1)
    print('n2is:',n2)
    print('n3 is:',n3)
    avg=(n1+n2+n3)/3
    avg1=round(avg,2)
    print(f'the average of {n1} , {n2} and {n3} is : {avg1}')
AVG(100,200)
# Out:
# n1 is: 100
# n2is: 200
# n3 is: 300
# the average of 100 , 200 and 300 is : 200.0

# %% [markdown]
# **note: default arguments always at last**

# %%
n1,n2,n3=100 # w
n1,n2=100,n3 # f
n1=100,n2,n3 # f
n1,n2=100,n3=100 # w
n1=100,n2,n3=100 # f
n1=100,n2=100,n3 # f
n1=100,n2=100,n3=100 # w

# %% [markdown]
# - functions with arguments
#
# - functions without arguments
#
# - functions with default arguments

# %%
def tax_cal():
    salary=eval(input('enter the salary:'))
    tax_per=eval(input('enter the tax:'))
    tax_pay=salary*tax_per/100
    print(tax_per)

tax_cal()
# Out:
# enter the salary: 10000
# enter the tax: 1000
# 1000

# %%
print("function without arguments")
def tax_cal():
    salary=eval(input('enter the salary:'))
    tax_per=eval(input('enter the tax:'))
    tax_pay=salary*tax_per/100
    print("the total tax pay :",tax_pay)

tax_cal()

print("function with arguments")
def tax_cal1(salary,tax_per):
    tax_pay=salary*tax_per/100
    print("the total tax pay :",tax_pay)

tax_cal1(1000,2000)

print("function with default arguments")
def tax_cal2(salary,tax_per=10):
    tax_pay=salary*tax_per/100
    print("the total tax pay :",tax_pay)

tax_cal2(5000)
# Out:
# function without argumrnts
# enter the salary: 10000
# enter the tax: 200
# the total tax pay : 20000.0
# function with arguments
# the total tax pay : 20000.0
# function with default arguments
# the total tax pay : 500.0

# %% [markdown]
# **analogy with the packages**

# %%
from random import randint,random

# %%
complex(3,4) # real=3, imag=4 3+4j
# Out:
# (3+4j)

# %%
complex(3) # real=3, imag=0 3+0j
# Out:
# (3+0j)

# %%
complex() # real=0, imag=0 0+0j
# Out:
# 0j

# %% [markdown]
# - now onwards whenever u see any package
#
# - always do **shift+tab** inside the brackets and observe 3 things
#
# - with or without or default arguments

# %%
def add(a,b,c):
    print("a:",a)
    print("b:",b)
    print("c:",c)
    summ=a+b+c
    print(f'the summation of {a},{b} and {c} is: {summ}')
add(100,200,300)
# Out:
# a: 100
# b: 200
# c: 300
# the summation of 100,200 and 300 is: 600

# %% [markdown]
# **case-1**

# %%
def add(a,b,c=300):
    print("a:",a)
    print("b:",b)
    print("c:",c)
    summ=a+b+c
    print(f'the summation of {a},{b} and {c} is: {summ}')
add(100,200)
# Out:
# a: 100
# b: 200
# c: 300
# the summation of 100,200 and 300 is: 600

# %% [markdown]
# **case-2**

# %%
def add(a,b,c=400):
    print("a:",a)
    print("b:",b)
    print("c:",c)
    summ=a+b+c
    print(f'the summation of {a},{b} and {c} is: {summ}')
add(100,200,600)
# Out:
# a: 100
# b: 200
# c: 600
# the summation of 100,200 and 600 is: 900

# %% [markdown]
# - in above case we already provided default value c=400
#
# - but while we call the function c value become 600
#
# - step-1:define the function : while define what is the value 400
#
# - step-2:call the function : while call the function what is the value 600
#
# - step-3:running the function : while running the function what is the value : 600

# %%
def add(a,b,c=400):
    c=1000
    print("a:",a)
    print("b:",b)
    print("c:",c)
    summ=a+b+c
    print(f'the summation of {a},{b} and {c} is: {summ}')
add(100,200,600)
# while defining c=400
# while calling c=600
# while running c=1000
# Out:
# a: 100
# b: 200
# c: 1000
# the summation of 100,200 and 1000 is: 1300

# %% [markdown]
# **global variable vs local variable**

# %% [markdown]
# - the variables outside the function is called **global variables**
#
#    - global variables can be use anywhere
#
#    - global variables can be use inside the function also outside the function
#
# - the variables inside the function is called **local variables**
#
#    - local variables can be use inside the function
#
#    - local variables can not be use outside the function

# %%
def addition():
    n1=100
    n2=200
    summ=n1+n2
    print(f'the summation of {n1} and {n2} is : {summ}')
addition()
# Out:
# the summation of 100 and 200 is : 300

# %%
n1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 n1
#
# NameError: name 'n1' is not defined

# %%
n1=1000
n2=2000
def addition():
    summ=n1+n2
    print(f'the summation of {n1} and {n2} is : {summ}')
addition()
# Out:
# the summation of 1000 and 2000 is : 3000

# %%
n1
# Out:
# 1000

# %% [markdown]
# **how to convert local variable to global variable**
#
# - if we want to use summ variable outside the function
#
# -  then initialise sum as global also using global keyword

# %%
n1=1000
n2=2000
def addition():
    global summ # local variable converted into global variable
    summ=n1+n2
    print(f'the summation of {n1} and {n2} is : {summ}')
addition()
# Out:
# the summation of 1000 and 2000 is : 3000

# %%
s=0
def add1(): 
    global s1
    n1=100
    s1=s+n1
    print(s1)
add1()
# Out:
# 100

# %%
s1
# Out:
# 100

# %%
s=0
def add1(): 
    n1=100
    s=s+n1
    print(s1)
add1()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[22], line 6
#       4     s=s+n1
#       5     print(s1)
# ----> 6 add1()
#
# Cell In[22], line 4, in add1()
#       2 def add1():
#       3     n1=100
# ----> 4     s=s+n1
#       5     print(s1)
#
# UnboundLocalError: cannot access local variable 's' where it is not associated with a value

# %% [markdown]
# - in above example **s** is not initialised
#
# - we might think name error will come
#
# - but inside function we will get **unbound local error**

# %%
s=0
def add1(): 
    global s1
    n1=100
    s1=summ1+n1
    print(s1)
add1()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 7
#       5     s1=sum1+n1
#       6     print(s1)
# ----> 7 add1()
#
# Cell In[23], line 5, in add1()
#       3 global s1
#       4 n1=100
# ----> 5 s1=sum1+n1
#       6 print(s1)
#
# NameError: name 'sum1' is not defined

# %%
def add3(): 
    n1=100
    summ2=100
    summ2=summ2+n1
    print(summ2)
add3()
# Out:
# 200

# %%
def avg(a,b,c):
    add=a+b+c
    avg1=add/3
    print(add,avg1)
avg(10,20,30)
# Out:
# 60 20.0

# %%
def avg(a,b,c):
    global ADD, AVG1
    ADD=a+b+c
    AVG1=ADD/3
    print(ADD,AVG1)
avg(10,20,30)
# Out:
# 60 20.0

# %%
ADD
# Out:
# 60

# %%
AVG1
# Out:
# 20.0

# %%
# wap ask the user enter a number
# print it is an even or odd

def fun():
    num=eval(input("enter a number:"))
    if num%2==0:
        print(f"{num} is even")
    else:
        print(f"{num} is odd")

fun()
# Out:
# enter a number: 25
# 25 is odd

# %%
def fun1(num):
    if num%2==0:
        print(f"{num} is even")
    else:
        print(f"{num} is odd")

fun1(20)
# Out:
# 20 is even

# %%
def fun2(num=35):
    if num%2==0:
        print(f"{num} is even")
    else:
        print(f"{num} is odd")

fun2()
# Out:
# 35 is odd

# %%
def fun1(num):
    global num
    if num%2==0:
        print(f"{num} is even")
    else:
        print(f"{num} is odd")

fun1(20)
# Out:
#   Cell In[12], line 2
#     global num
#     ^
# SyntaxError: name 'num' is parameter and global

# %% [markdown]
# **parameter vs variable**

# %% [markdown]
# - parameters also called as arguments
#
#   - this always inside the function brackets
#
# - variables either outside the function or inside the function

# %% [markdown]
# **return statements**

# %% [markdown]
# - return means function is giving something
#
# - we know that local variables cannot use outside the function
#
# - in order to use local variables outside the function, we have two methods
#
#     - global
#
#     - return

# %%
def add():
    global c
    a=10
    b=20
    c=a+b
    print(c)

add()
# Out:
# 30

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 c
#
# NameError: name 'c' is not defined

# %%
c
# Out:
# 30

# %%
def add():
    a=10
    b=20
    c=a+b
    print(c)
    return(c)

c=add()
# Out:
# 30

# %%
value=10,20
value
# Out:
# (10, 20)

# %%
val1,val2=10,20
val2
# Out:
# 20

# %%
val1,val2=10
val1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 val1,val2=10
#       2 val1
#
# TypeError: cannot unpack non-iterable int object

# %%
def add():
    a=10
    b=20
    c=a+b
    return(a,c)

a,c=add()
print(a)
print(c)
# Out:
# 10
# 30

# %%
def avg(a,b,c):
    summ=a+b+c
    AVG=summ/3
    return(summ,AVG)

summ,AVG=avg(10,20,30)
print(summ)
print(AVG)
# Out:
# 60
# 20.0

# %%
def fun():
    numm2=eval(input("enter a number:"))
    if numm2%2==0:
        val=10
        print(f"{numm2} is even")
        return(numm2)
    else:
        val=20
        print(f"{numm2} is odd")
        return(numm2)
    ret
numm2=fun()
# Out:
# enter a number: 20
# 20 is even

# %%
def fun(numm2):
    if numm2%2==0:
        print(f"{numm2} is even")
        return(numm2)
    else:
        print(f"{numm2} is odd")
        return(numm2)

numm2=fun(10)
# Out:
# 10 is even

# %%
def fun(numm2=20):
    if numm2%2==0:
        print(f"{numm2} is even")
        return(numm2)
    else:
        print(f"{numm2} is odd")
        return(numm2)

numm2=fun()
# Out:
# 20 is even

# %%
def fun():
    numm2=eval(input("enter a number:"))
    if numm2%2==0:
        return(f"{numm2} is even")
    else:
        return(f"{numm2} is odd")
    
numm2=fun()
print(numm2)
# Out:
# enter a number: 20
# 20 is even

# %%
def fun(numm2):
    if numm2%2==0:
        return(f"{numm2} is even")
    else:
        return(f"{numm2} is odd")
    
numm2=fun(20)
print(numm2)
# Out:
# 20 is even

# %%
def fun(numm2=200):
    if numm2%2==0:
        return(f"{numm2} is even")
    else:
        return(f"{numm2} is odd")
    
numm2=fun()
print(numm2)
# Out:
# 200 is even

# %% [markdown]
# **function in function**

# %%
def greet1():
    print('hello good morning')

def greet2():
    print('hello good night')
greet1()
greet2()
# Out:
# hello good morning
# hello good night

# %%
def greet1():
    print('hello good morning')

def greet2():
    print('hello good night')
    greet1()

greet2()
# Out:
# hello good night
# hello good morning

# %%
def greet1():
    print('hello good morning')
    greet2()
def greet2():
    print('hello good night')
greet1()
# Out:
# hello good morning
# hello good night

# %%
def greet1():
    print('hello good morning')
    greet2()
def greet2():
    print('hello good night')
    greet2()
greet1()
# Out:
# hello good morning
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# hello good night
# ...

# %%
def add(n):
    if n==0:
        return(0)
    else:
        return(n+add(n-1))
add(5)
# step-1:  n=5 if F else 5+add(4)
#          n=5 if F else 5+4+add(3)
#          n=5 if F else 5+4+3+add(2)
#          n=5 if F else 5+4+3+2+add(1) 
#          n=5 if F else 5+4+3+2+1+add(0)
#          n=5 if F else 5+4+3+2+1+0
# Out:
# 15

# %%
# Q1) factorial recursion 5!=5*4*3*2*1
# Q2) calculator program

# step-1: create 4 functions 
# def add(a,b):
# return(a+b)
# def mul
# def div
# def sub

# print('enter 1 for add 2 sub so on')

# %%
def fact(n):
    if n==0:
        return(1)
    else:
        return(n*fact(n-1))
fact(5)
# Out:
# 120

# %%
print('enter 1 for add')
print('enter 2 for sub')
print('enter 3 for mul')
print('enter 4 for div')
def main():
    option=eval(input('enter between 1 to 4:'))
    if option==1:
        a=10
        b=20
        add=a+b
        return(add)
        print(f'the addition of {a} and {b} is : {add}')
    elif option==2:
        a=10
        b=20
        sub=a-b
        return(sub)
        print(f'the subtraction of {a} and {b} is : {sub}')
    elif option==3:
        a=10
        b=20
        mul=a*b
        return(mul)
        print(f'the multiplication of {a} and {b} is : {mul}')
    elif option==4:
        a=10
        b=20
        div=a/b
        return(div)
        print(f'the division of {a} and {b} is : {div}')
main()
# Out:
# enter 1 for add
# enter 2 for sub
# enter 3 for mul
# enter 4 for div
# enter between 1 to 4: 1
# 30
